# %% [markdown]
# # 1. Loading data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('Tesla.csv')

# %%
data.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %% [markdown]
# # 2. Splitting data as train and validation

# %%
length_data = len(data)
split_ratio = 0.7
length_train = round(length_data * split_ratio)
length_validation = length_data - length_train
print("Data length:",length_data)
print("Train data length :", length_train)
print("Validation data lenth :", length_validation)
# Out:
# Data length: 1692
# Train data length : 1184
# Validation data lenth : 508

# %%
train_data = data[:length_train].iloc[:,:2]
train_data['Date'] = pd.to_datetime(train_data['Date'])
train_data
# Out:
#            Date        Open
# 0    2010-06-29   19.000000
# 1    2010-06-30   25.790001
# 2    2010-07-01   25.000000
# 3    2010-07-02   23.000000
# 4    2010-07-06   20.000000
# ...         ...         ...
# 1179 2015-03-06  199.210007
# 1180 2015-03-09  194.389999
# 1181 2015-03-10  188.460007
# 1182 2015-03-11  191.149994
# 1183 2015-03-12  193.750000
#
# [1184 rows x 2 columns]

# %%
validation_data = data[length_train:].iloc[:,:2]
validation_data['Date'] = pd.to_datetime(validation_data['Date'])
validation_data
# Out:
#            Date        Open
# 1184 2015-03-13  188.949997
# 1185 2015-03-16  192.000000
# 1186 2015-03-17  195.429993
# 1187 2015-03-18  194.960007
# 1188 2015-03-19  202.000000
# ...         ...         ...
# 1687 2017-03-13  244.820007
# 1688 2017-03-14  246.110001
# 1689 2017-03-15  257.000000
# 1690 2017-03-16  262.399994
# 1691 2017-03-17  264.000000
#
# [508 rows x 2 columns]

# %% [markdown]
# # 3. Creating train dataset from train split
# ### We will get Open column as our dataset
# ### Dataset to be converted to array by adding .values

# %%
dataset_train = train_data.Open.values
dataset_train.shape
# Out:
# (1184,)

# %%
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (1184, 1)

# %% [markdown]
# ## 4. Normalization/Feature Scaling
#
# * Dataset values will be 0 and 1 after scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))

# scaling dataset
dataset_train_scaled = scaler.fit_transform(dataset_train)
dataset_train_scaled.shape
# Out:
# (1184, 1)

# %%
plt.subplots(figsize = (15,6))
plt.plot(dataset_train_scaled)
plt.xlabel("Days as 1st, 2nd, 3rd..")
plt.show()

# %% [markdown]
# ## 5. Creating X_train and y_train from Train data

# %%
X_train = []
y_train = []

time_step = 50

for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:
                                        i,0])
    y_train.append(dataset_train_scaled[i,0])

X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print("Shape of X_train before reshape :", X_train.shape)
print("Shape of y_train before reshape :", y_train.shape)
# Out:
# Shape of X_train before reshape : (1134, 50)
# Shape of y_train before reshape : (1134,)

# %% [markdown]
# ## Reshape

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("Shape of X_train after reshape:", X_train.shape)
print("Shape of y_train after reshape:", y_train.shape)
# Out:
# Shape of X_train after reshape: (1134, 50, 1)
# Shape of y_train after reshape: (1134, 1)

# %% [markdown]
# * Shape of X_train: 1134*50*1
# * That means we have 1134 rows, each row has 50 rows and 1 column
# * Lets check the first row:it has 50 rows(open prices of 49 days)

# %%
X_train[0]
# Out:
# array([[0.01053291],
#        [0.03553936],
#        [0.03262991],
#        [0.02526425],
#        [0.01421574],
#        [0.00095754],
#        [0.        ],
#        [0.00530328],
#        [0.00666594],
#        [0.00460354],
#        [0.00662911],
#        [0.01399478],
#        [0.01679373],
#        [0.01926123],
#        [0.02102899],
#        [0.01664641],
#        [0.01605716],
#        [0.01859832],
#        [0.01973999],
#        [0.01756712],
#        [0.0162413 ],
#        [0.01705153],
#        [0.01495231],
#        [0.01605716],
#        [0.01789858],
#        [0.02139727],
#        [0.01988731],
#        [0.01458403],
#        [0.01384746],
#        [0.01292675],
#        [0.00939123],
#        [0.0061135 ],
#        [0.00751299],
#        [0.00850735],
#        [0.01038559],
#        [0.01270578],
#        [0.00883881],
#        [0.00924392],
#        [0.01086436],
#        [0.01145362],
#        [0.01112216],
#        [0.01381063],
#        [0.01329503],
#        [0.0131109 ],
#        [0.01296358],
#        [0.01281627],
#        [0.0155784 ],
#        [0.01741981],
#        [0.01646228],
#        [0.01664641]])

# %% [markdown]
# * Chcek the first in y_train
# * It is the price of 50th day

# %%
y_train[0]
# Out:
# array([0.01789858])

# %% [markdown]
# ## 6.Creating RNN model

# %%
# importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# initializing the RNN
regressor = Sequential()

# adding first RNN layer and dropout regulatization
regressor.add(
    SimpleRNN(units = 50,
              activation = "tanh",
              return_sequences = True,
              input_shape = (X_train.shape[1],1))
             )

regressor.add(
    Dropout(0.2)
             )


# adding second RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50,
              activation = "tanh",
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding third RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50,
              activation = "tanh",
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding fourth RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50)
             )

regressor.add(
    Dropout(0.2)
             )

# adding the output layer
regressor.add(Dense(units = 1))

# compiling RNN
regressor.compile(
    optimizer = "adam",
    loss = "mean_squared_error",
    metrics = ["accuracy"])

# fitting the RNN
history = regressor.fit(X_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 12s 54ms/step - loss: 0.3768 - accuracy: 8.8183e-04
# Epoch 2/50
# 36/36 [==============================] - 2s 69ms/step - loss: 0.2289 - accuracy: 8.8183e-04
# Epoch 3/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.1492 - accuracy: 0.0000e+00
# Epoch 4/50
# 36/36 [==============================] - 2s 43ms/step - loss: 0.1197 - accuracy: 8.8183e-04
# Epoch 5/50
# 36/36 [==============================] - 2s 42ms/step - loss: 0.0879 - accuracy: 0.0000e+00
# Epoch 6/50
# 36/36 [==============================] - 2s 42ms/step - loss: 0.0617 - accuracy: 8.8183e-04
# Epoch 7/50
# 36/36 [==============================] - 1s 42ms/step - loss: 0.0560 - accuracy: 8.8183e-04
# Epoch 8/50
# 36/36 [==============================] - 2s 45ms/step - loss: 0.0460 - accuracy: 8.8183e-04
# Epoch 9/50
# 36/36 [==============================] - 2s 44ms/step - loss: 0.0443 - accuracy: 8.8183e-04
# Epoch 10/50
# 36/36 [==============================] - 3s 78ms/step - loss: 0.0381 - accuracy: 8.8183e-04
# Epoch 11/50
# 36/36 [==============================] - 2s 48ms/step - loss: 0.0293 - accuracy: 8.8183e-04
# Epoch 12/50
# 36/36 [==============================] - 2s 43ms/step - loss: 0.0260 - accuracy: 8.8183e-04
# Epoch 13/50
# 36/36 [==============================] - 2s 43ms/step - loss: 0.0269 - accuracy: 8.8183e-04
# Epoch 14/50
# 36/36 [==============================] - 2s 46ms/step - loss: 0.0238 - accuracy: 8.8183e-04
# Epoch 15/50
# 36/36 [==============================] - 2s 44ms/step - loss: 0.0199 - accuracy: 8.8183e-04
# Epoch 16/50
# 36/36 [==============================] - 2s 44ms/step - loss: 0.0191 - accuracy: 8.8183e-04
# Epoch 17/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.0187 - accuracy: 8.8183e-04
# Epoch 18/50
# 36/36 [==============================] - 2s 65ms/step - loss: 0.0171 - accuracy: 8.8183e-04
# Epoch 19/50
# 36/36 [==============================] - 2s 47ms/step - loss: 0.0180 - accuracy: 8.8183e-04
# Epoch 20/50
# 36/36 [==============================] - 2s 46ms/step - loss: 0.0153 - accuracy: 8.8183e-04
# Epoch 21/50
# 36/36 [==============================] - 2s 46ms/step - loss: 0.0155 - accuracy: 8.8183e-04
# Epoch 22/50
# 36/36 [==============================] - 2s 45ms/step - loss: 0.0161 - accuracy: 8.8183e-04
# Epoch 23/50
# 36/36 [==============================] - 2s 42ms/step - loss: 0.0144 - accuracy: 8.8183e-04
# Epoch 24/50
# 36/36 [==============================] - 2s 48ms/step - loss: 0.0133 - accuracy: 8.8183e-04
# Epoch 25/50
# 36/36 [==============================] - 3s 81ms/step - loss: 0.0124 - accuracy: 8.8183e-04
# Epoch 26/50
# 36/36 [==============================] - 2s 42ms/step - loss: 0.0113 - accuracy: 8.8183e-04
# Epoch 27/50
# 36/36 [==============================] - 2s 45ms/step - loss: 0.0115 - accuracy: 8.8183e-04
# Epoch 28/50
# 36/36 [==============================] - 2s 46ms/step - loss: 0.0113 - accuracy: 8.8183e-04
# Epoch 29/50
# 36/36 [==============================] - 2s 48ms/step - loss: 0.0099 - accuracy: 8.8183e-04
# Epoch 30/50
# 36/36 [==============================] - 2s 42ms/step - loss: 0.0095 - accuracy: 8.8183e-04
# Epoch 31/50
# 36/36 [==============================] - 2s 46ms/step - loss: 0.0095 - accuracy: 8.8183e-04
# Epoch 32/50
# 36/36 [==============================] - 2s 69ms/step - loss: 0.0086 - accuracy: 8.8183e-04
# Epoch 33/50
# 36/36 [==============================] - 2s 65ms/step - loss: 0.0079 - accuracy: 8.8183e-04
# Epoch 34/50
# 36/36 [==============================] - 2s 46ms/step - loss: 0.0072 - accuracy: 8.8183e-04
# Epoch 35/50
# 36/36 [==============================] - 2s 44ms/step - loss: 0.0079 - accuracy: 8.8183e-04
# Epoch 36/50
# 36/36 [==============================] - 2s 43ms/step - loss: 0.0064 - accuracy: 8.8183e-04
# Epoch 37/50
# 36/36 [==============================] - 2s 46ms/step - loss: 0.0069 - accuracy: 8.8183e-04
# Epoch 38/50
# 36/36 [==============================] - 2s 45ms/step - loss: 0.0078 - accuracy: 8.8183e-04
# Epoch 39/50
# 36/36 [==============================] - 2s 57ms/step - loss: 0.0060 - accuracy: 8.8183e-04
# Epoch 40/50
# 36/36 [==============================] - 2s 68ms/step - loss: 0.0057 - accuracy: 8.8183e-04
# Epoch 41/50
# 36/36 [==============================] - 2s 47ms/step - loss: 0.0060 - accuracy: 8.8183e-04
# Epoch 42/50
# 36/36 [==============================] - 2s 43ms/step - loss: 0.0052 - accuracy: 8.8183e-04
# Epoch 43/50
# 36/36 [==============================] - 2s 42ms/step - loss: 0.0060 - accuracy: 8.8183e-04
# Epoch 44/50
# 36/36 [==============================] - 2s 45ms/step - loss: 0.0060 - accuracy: 8.8183e-04
# Epoch 45/50
# 36/36 [==============================] - 2s 42ms/step - loss: 0.0050 - accuracy: 8.8183e-04
# Epoch 46/50
# 36/36 [==============================] - 2s 50ms/step - loss: 0.0049 - accuracy: 8.8183e-04
# Epoch 47/50
# 36/36 [==============================] - 3s 76ms/step - loss: 0.0043 - accuracy: 8.8183e-04
# Epoch 48/50
# 36/36 [==============================] - 2s 45ms/step - loss: 0.0049 - accuracy: 8.8183e-04
# Epoch 49/50
# 36/36 [==============================] - 2s 47ms/step - loss: 0.0055 - accuracy: 8.8183e-04
# Epoch 50/50
# 36/36 [==============================] - 2s 64ms/step - loss: 0.0042 - accuracy: 8.8183e-04

# %% [markdown]
# ## 7.Evaluating Model

# %%
# Losses
history.history["loss"]
# Out:
# [0.37679508328437805,
#  0.22889144718647003,
#  0.14916424453258514,
#  0.11965827643871307,
#  0.08786240220069885,
#  0.061666786670684814,
#  0.056025415658950806,
#  0.04602184146642685,
#  0.04428960755467415,
#  0.038082901388406754,
#  0.029292860999703407,
#  0.025974739342927933,
#  0.02688530832529068,
#  0.023752303794026375,
#  0.019884176552295685,
#  0.01912861131131649,
#  0.018741324543952942,
#  0.017062349244952202,
#  0.01800892874598503,
#  0.015311685390770435,
#  0.015494205057621002,
#  0.016138900071382523,
#  0.014384513720870018,
#  0.013290615752339363,
#  0.01239368412643671,
#  0.011346143670380116,
#  0.011499561369419098,
#  0.01133765373378992,
#  0.009896955452859402,
#  0.009463479742407799,
#  0.009466609917581081,
#  0.00859794206917286,
#  0.007875976152718067,
#  0.007176003884524107,
#  0.007858870550990105,
#  0.006406651344150305,
#  0.00685239490121603,
#  0.007764026522636414,
#  0.005957095418125391,
#  0.00573109183460474,
#  0.005960505455732346,
#  0.005213454831391573,
#  0.006004028022289276,
#  0.005979923065751791,
#  0.00502112926915288,
#  0.004872316960245371,
#  0.0043173898011446,
#  0.004944277927279472,
#  0.005477791652083397,
#  0.004202699288725853]

# %%
# Plotting Loss vs Epochs
plt.figure(figsize =(10,7))
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("Simple RNN model, Loss vs Epoch")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plotting Accuracy vs Epochs
plt.figure(figsize =(10,5))
plt.plot(history.history["accuracy"])
plt.xlabel("Epochs")
plt.ylabel("Accuracies")
plt.title("Simple RNN model, Accuracy vs Epoch")
plt.show()

# %% [markdown]
# ## Model predictions for train data

# %%
y_pred = regressor.predict(X_train) #predictions
# scaling back from 0-1 to original
y_pred = scaler.inverse_transform(y_pred)
y_pred.shape
# Out:
# 36/36 [==============================] - 1s 12ms/step
# (1134, 1)

# %%
# scaling back from 0-1 to original
y_train = scaler.inverse_transform(y_train)
y_train.shape
# Out:
# (1134, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred, color = "b", label = "y_pred" )
plt.plot(y_train, color = "g", label = "y_train")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Predictions with input X_train vs y_train")
plt.legend()
plt.show()

# %% [markdown]
# ## 8.Creating Test Dataset from Validation Data
# * Converting array and scaling

# %%
# getting "open" column and converting to array
dataset_validation = validation_data.Open.values
# converting 1D to 2D array
dataset_validation = np.reshape(dataset_validation,(-1,1))
# scaling open values to between 0 and 1
scaled_dataset_validation = scaler.fit_transform(dataset_validation)
print("Shape of scaled validation dataset :",scaled_dataset_validation.shape)
# Out:
# Shape of scaled validation dataset : (508, 1)

# %% [markdown]
# ### Creating X_text and y_test

# %%
# Creating X_text and y_test
X_test = []
y_test = []

for i in range(time_step, length_validation):
    X_test.append(scaled_dataset_validation[i-time_step:i,0])
    y_test.append(scaled_dataset_validation[i,0])

# %% [markdown]
# ### Converting to array

# %%
# Converting to array
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
print("Shape of X_test before reshape:", X_test.shape)
print("Shape of y_test before reshape:", y_test.shape)
# Out:
# Shape of X_test before reshape: (458, 50)
# Shape of y_test before reshape: (458,)

# %% [markdown]
# ### Reshape

# %%
# reshape to 3D array
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
# resahpe to 2D array
y_test = np.reshape(y_test, (-1,1))

# %%
print("Shape of X_test after reshape :",X_test.shape)
print("Shape of y_test after reshape :",y_test.shape)
# Out:
# Shape of X_test after reshape : (458, 50, 1)
# Shape of y_test after reshape : (458, 1)

# %% [markdown]
# ## 9.Evaluating with Validation Data

# %%
# predictions with X_test data
y_pred_of_test = regressor.predict(X_test)
# scaling back from 0-1 to original
y_pred_of_test = scaler.inverse_transform(y_pred_of_test)
print("Shape of y_pred_of_test :",y_pred_of_test.shape)
# Out:
# 15/15 [==============================] - 0s 13ms/step
# Shape of y_pred_of_test : (458, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred_of_test, label = "y_pred_of_test", c = "orange")
plt.plot(scaler.inverse_transform(y_test), label = "y_test", c = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Prediction with input X_test vs y_test")
plt.legend()
plt.show()

# %%
# Visualisation
plt.subplots(figsize =(30,12))
plt.plot(train_data.Date, train_data.Open, label = "train_data", color = "b")
plt.plot(validation_data.Date, validation_data.Open, label = "validation_data", color = "g")
plt.plot(train_data.Date.iloc[time_step:], y_pred, label = "y_pred", color = "r")
plt.plot(validation_data.Date.iloc[time_step:], y_pred_of_test, label = "y_pred_of_test", color = "orange")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Train-Validation-Prediction")
plt.legend()
plt.show()

# %% [markdown]
# ## 10.Creating LSTM Model

# %%
y_train = scaler.fit_transform(y_train)

# %%
from keras.layers import LSTM

model_lstm = Sequential()
# 64 lstm neuron block
model_lstm.add(LSTM(64,return_sequences = True, input_shape = (X_train.shape[1],1)))
model_lstm.add(LSTM(64, return_sequences = False))
model_lstm.add(Dense(32))
model_lstm.add(Dense(1))
model_lstm.compile(loss = "mean_squared_error",optimizer = "adam", metrics = ["accuracy"])
history2 = model_lstm.fit(X_train, y_train, epochs = 10, batch_size = 10)
# Out:
# Epoch 1/10
# 114/114 [==============================] - 10s 40ms/step - loss: 0.0093 - accuracy: 0.0018
# Epoch 2/10
# 114/114 [==============================] - 7s 58ms/step - loss: 0.0014 - accuracy: 0.0018
# Epoch 3/10
# 114/114 [==============================] - 4s 39ms/step - loss: 0.0016 - accuracy: 0.0018
# Epoch 4/10
# 114/114 [==============================] - 4s 39ms/step - loss: 0.0011 - accuracy: 0.0018
# Epoch 5/10
# 114/114 [==============================] - 6s 50ms/step - loss: 9.4251e-04 - accuracy: 0.0018
# Epoch 6/10
# 114/114 [==============================] - 4s 39ms/step - loss: 8.8931e-04 - accuracy: 0.0018
# Epoch 7/10
# 114/114 [==============================] - 4s 39ms/step - loss: 0.0010 - accuracy: 0.0018
# Epoch 8/10
# 114/114 [==============================] - 6s 53ms/step - loss: 9.4104e-04 - accuracy: 0.0018
# Epoch 9/10
# 114/114 [==============================] - 4s 39ms/step - loss: 7.1908e-04 - accuracy: 0.0018
# Epoch 10/10
# 114/114 [==============================] - 5s 42ms/step - loss: 6.5492e-04 - accuracy: 0.0018

# %% [markdown]
# ## 11. Evaluating LSTM Model

# %%
plt.figure(figsize =(10,5))
plt.plot(history2.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("LSTM model, Accuracy vs Epoch")
plt.show()

# %%
plt.subplots(figsize =(30,12))
plt.plot(scaler.inverse_transform(model_lstm.predict(X_test)), label = "y_pred_of_test", c = "orange" )
plt.plot(scaler.inverse_transform(y_test), label = "y_test", color = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("LSTM model, Predictions with input X_test vs y_test")
plt.legend()
plt.show()
# Out:
# 15/15 [==============================] - 1s 19ms/step

# %% [markdown]
# ## 12.Future price prediction
# * Which day is the last day in our data?

# %%
data.iloc[-1]
# Out:
# Date          3/17/2017
# Open              264.0
# High         265.329987
# Low          261.200012
# Close             261.5
# Volume          6475900
# Adj Close         261.5
# Name: 1691, dtype: object

# %% [markdown]
# * We can predict the open price for the day after 3/17/2017--> for 3/18/2017.
# * We will use last 50 days Open price as input of our model for this prediction
# * Let us prepare it:

# %%
X_input = data.iloc[-time_step:].Open.values               # getting last 50 rows and converting to array
X_input = scaler.fit_transform(X_input.reshape(-1,1))      # converting to 2D array and scaling
X_input = np.reshape(X_input, (1,50,1))                    # reshaping : converting to 3D array
print("Shape of X_input :", X_input.shape)
X_input
# Out:
# Shape of X_input : (1, 50, 1)
# array([[[0.        ],
#         [0.00946363],
#         [0.04731867],
#         [0.10354429],
#         [0.04917441],
#         [0.04898868],
#         [0.06643166],
#         [0.19075893],
#         [0.18983106],
#         [0.38652815],
#         [0.35331247],
#         [0.36054942],
#         [0.43755803],
#         [0.57320468],
#         [0.5171645 ],
#         [0.46316584],
#         [0.48450549],
#         [0.42345532],
#         [0.49415485],
#         [0.40675446],
#         [0.47300067],
#         [0.45611434],
#         [0.58953431],
#         [0.57394708],
#         [0.7390982 ],
#         [0.80478773],
#         [0.82241588],
#         [0.97624793],
#         [0.99424758],
#         [0.94971253],
#         [0.73074763],
#         [0.90981655],
#         [1.        ],
#         [0.69734648],
#         [0.48691791],
#         [0.40359993],
#         [0.32974585],
#         [0.51512331],
#         [0.43217682],
#         [0.45128979],
#         [0.39877539],
#         [0.47318612],
#         [0.38188907],
#         [0.39357964],
#         [0.36722971],
#         [0.34143643],
#         [0.36537397],
#         [0.56745225],
#         [0.66765626],
#         [0.69734648]]])

# %%
simple_RNN_prediction = scaler.inverse_transform(regressor.predict(X_input))
LSTM_prediction = scaler.inverse_transform(model_lstm.predict(X_input))

print("Simple RNN, Open price prediction for 3/18/2017      :", simple_RNN_prediction[0,0])
print("LSTM prediction, Open price prediction for 3/18/2017 :", LSTM_prediction[0,0])
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Simple RNN, Open price prediction for 3/18/2017      : 254.82051
# LSTM prediction, Open price prediction for 3/18/2017 : 254.2091
